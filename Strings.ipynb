# %%
"George" # 'George'

# %%
print("George") # George

# %%
name = "Lisa"

# %%
name # 'Lisa'

# %%
y = 10  # you have to stringify y first before using it with a string

print( str(y) +  " " + "Dollars") # 10 Dollars

# %%
print("I'm fine") # I'm fine

# %%
print("I\'m fine") # I'm fine

# %%
print('press "Enter"') # press "Enter"

# %%
print(3, 5) # 3 5
