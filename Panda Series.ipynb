# %%
import pandas as pd

# %%
working_hours = [4,5,2,10]

# %%
working_hours_series = pd.Series(working_hours) # caps S for Series

working_hours_series

#0     4
#1     5
#2     2
#3    10
#dtype: int64
