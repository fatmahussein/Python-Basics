# %%
x = (1, 2, 3, 6)  # notice the parenthesis
x

# (1, 2, 3, 6)

# %%
y = 1, 2, 4, 7   #  pythons default are tuples
y

# (1, 2, 4, 7)

# %%
a, b, c = 1, 2, 3

c

# 3

# %%
x

x[2]

# 3

# %%
list_1 = [x, y] # joining the two tuples in a list
list_1

# [(1, 2, 3, 6), (1, 2, 4, 7)]

# %%
(age, years_of_school) = "30,17".split(",")  # separate with comma
print(age)
print(years_of_school)

# 30
# 17

# %%
def square_info(x):
    A = x ** 2
    P = x * 4
    print("Area and Perimeter :")
    return A,P

square_info(3) 

# Area and Perimeter :
# (9, 12)
