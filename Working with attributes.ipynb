# %%
import pandas as pd

# %%
series_a = pd.Series([10,20,30,40,50])
series_a

# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
series_a.dtype

# dtype('int64')

# %%
series_a.size

# 5

# %%
product_categories = pd.Series(['A', 'B', 'C', 'D'])
product_categories

# %%
product_categories.dtype

# dtype('O') => object , default for non-numeric dtype

# %%
product_categories.size

# 4
