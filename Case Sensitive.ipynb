# %%
x = 5

# %%
x
# Out:
# 5

# %%
y = 8

# %%
y
# Out:
# 8

# %%
Y # NameError Y is not defined; Python is case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Y
#
# NameError: name 'Y' is not defined
