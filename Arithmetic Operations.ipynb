# %%
 1 + 2
# Out:
# 3

# %%
15 / 3
# Out:
# 5.0

# %%
16 / 3
# Out:
# 5.333333333333333

# %%
16 % 3 # get remainder
# Out:
# 1

# %%
y =5 ** 3  # 5 power 3

# %%
y == 125 # boolean                  == equality
# Out:
# True
