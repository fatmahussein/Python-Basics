# %%
for n in range(10):
    print (n ** 2, end = " ")

# 0 1 4 9 16 25 36 49 64 81

# %%
for x in range(20):
    if x % 2 == 0 :
        print(x, end = " ")
    else:
        print("odd", end = " ")

# 0 odd 2 odd 4 odd 6 odd 8 odd 10 odd 12 odd 14 odd 16 odd 18 odd
