# %%
True and True # True

# %%
True and False # False

# %%
False and False # False

# %%
False or False # False

# %%
True or False # True

# %%
not True # False

# %%
not False # True

# %%
3 > 5 and 5 > 1 # False

# %%
True and not True # False

# %%
False and not True and True # False

# %%
True and not True or False # False

# %%
10 is not 12  # True

# %%
5 is 5 # True
